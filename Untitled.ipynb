# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')
# %matplotlib inline

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv(r'dataset_heart.csv')
df.head()
# Out:
#    age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0   70     1                4                     130                322
# 1   67     0                3                     115                564
# 2   57     1                2                     124                261
# 3   64     1                4                     128                263
# 4   74     0                2                     120                269
#
#    fasting blood sugar  resting electrocardiographic results  max heart rate  \
# 0                    0                                     2             109
# 1                    0                                     2             160
# 2                    0                                     0             141
# 3                    0                                     0             105
# 4                    0                                     2             121
#
# ...

# %%
df.shape
# Out:
# (270, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   270 non-null    int64
#  1   sex                                   270 non-null    int64
#  2   chest pain type                       270 non-null    int64
#  3   resting blood pressure                270 non-null    int64
#  4   serum cholestoral                     270 non-null    int64
#  5   fasting blood sugar                   270 non-null    int64
#  6   resting electrocardiographic results  270 non-null    int64
#  7   max heart rate                        270 non-null    int64
#  8   exercise induced angina               270 non-null    int64
#  9   oldpeak                               270 non-null    float64
#  10  ST segment                            270 non-null    int64
# ...

# %%
df.describe()
# Out:
#               age        sex   chest pain type  resting blood pressure  \
# count  270.000000  270.000000       270.000000              270.000000
# mean    54.433333    0.677778         3.174074              131.344444
# std      9.109067    0.468195         0.950090               17.861608
# min     29.000000    0.000000         1.000000               94.000000
# 25%     48.000000    0.000000         3.000000              120.000000
# 50%     55.000000    1.000000         3.000000              130.000000
# 75%     61.000000    1.000000         4.000000              140.000000
# max     77.000000    1.000000         4.000000              200.000000
#
#        serum cholestoral  fasting blood sugar  \
# count         270.000000           270.000000
# mean          249.659259             0.148148
# std            51.686237             0.355906
# min           126.000000             0.000000
# 25%           213.000000             0.000000
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex ', 'chest pain type', 'resting blood pressure',
#        'serum cholestoral', 'fasting blood sugar',
#        'resting electrocardiographic results', 'max heart rate',
#        'exercise induced angina', 'oldpeak', 'ST segment', 'major vessels',
#        'thal', 'heart disease'],
#       dtype='object')

# %%
cols = ['age', 'sex ', 'chest pain type', 'resting blood pressure',
       'serum cholestoral', 'fasting blood sugar',
       'resting electrocardiographic results', 'max heart rate',
       'exercise induced angina', 'oldpeak', 'ST segment', 'major vessels',
       'thal', 'heart disease']

n_rows = 2
n_cols = 7
o = 0

fig, ax = plt.subplots(n_rows, n_cols, figsize = (25, 17))

for r in range(n_rows):
    for c in range(n_cols):
        i = r*n_cols + r
        o +=1
        if i<len(cols):
            ax_i = ax[r,c]
            sns.countplot(data = df, x = cols[o-1], palette = 'colorblind', ax = ax_i)
#         print (o)

# %%
cat_cols = ['sex ', 'chest pain type', 'fasting blood sugar',
       'resting electrocardiographic results', 'exercise induced angina', 'ST segment', 'major vessels',
       'thal', 'heart disease']
for col in cat_cols:
    df[col] = df[col].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   270 non-null    int64
#  1   sex                                   270 non-null    object
#  2   chest pain type                       270 non-null    object
#  3   resting blood pressure                270 non-null    int64
#  4   serum cholestoral                     270 non-null    int64
#  5   fasting blood sugar                   270 non-null    object
#  6   resting electrocardiographic results  270 non-null    object
#  7   max heart rate                        270 non-null    int64
#  8   exercise induced angina               270 non-null    object
#  9   oldpeak                               270 non-null    float64
#  10  ST segment                            270 non-null    object
# ...

# %%
num_cols = [col for col in cols if df[col].dtype != 'object']

print (num_cols)
# Out:
# ['age', 'resting blood pressure', 'serum cholestoral', 'max heart rate', 'oldpeak']

# %%
cat1 = ['sex ', 'chest pain type', 'fasting blood sugar',
       'resting electrocardiographic results', 'exercise induced angina', 'ST segment', 'major vessels',
       'thal']
n_rows = 2
n_cols = 4
o = 0

fig, ax = plt.subplots(n_rows, n_cols, figsize = (25, 17))

for r in range(n_rows):
    for c in range(n_cols):
        i = r*n_cols + r
        o +=1
        if i<len(cat1):
            ax_i = ax[r,c]
            sns.countplot(data = df, x = cat1[o-1], palette = 'colorblind', ax = ax_i, hue = 'heart disease')
#         print (o)

# %%
plt.figure(figsize = (15, 8))
plotnumber = 1

for col in num_cols:
    if plotnumber <= len(num_cols):
        ax = plt.subplot(1, 5, plotnumber)
        sns.distplot(df[col])
        plt.xlabel(col)
        
    plotnumber +=1

# %%
sns.pairplot(data = df[['age', 'resting blood pressure', 'serum cholestoral', 'max heart rate', 'oldpeak', 'heart disease']], hue = 'heart disease', corner = True)

# %% [markdown]
#   -- 1. age
#   -- 2. sex
#   -- 3. chest pain type  (4 values)
#   -- 4. resting blood pressure
#   -- 5. serum cholestoral in mg/dl
#   -- 6. fasting blood sugar > 120 mg/dl
#   -- 7. resting electrocardiographic results  (values 0,1,2)
#   -- 8. maximum heart rate achieved
#   -- 9. exercise induced angina
#   -- 10. oldpeak = ST depression induced by exercise relative to rest
#   -- 11. the slope of the peak exercise ST segment
#   -- 12. number of major vessels (0-3) colored by flourosopy
#   -- 13. thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#   -- 14. Target(Absence (1) or presence (2) of heart disease)

# %%
# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()

# for col in cat_cols:
#     df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    age sex  chest pain type  resting blood pressure  serum cholestoral  \
# 0   70    1               4                     130                322
# 1   67    0               3                     115                564
# 2   57    1               2                     124                261
# 3   64    1               4                     128                263
# 4   74    0               2                     120                269
#
#   fasting blood sugar resting electrocardiographic results  max heart rate  \
# 0                   0                                    2             109
# 1                   0                                    2             160
# 2                   0                                    0             141
# 3                   0                                    0             105
# 4                   0                                    2             121
#
#   exercise induced angina  oldpeak ST segment major vessels thal heart disease
# ...

# %%
# corr_matrix = x.corr()

# %%
# import seaborn as sns
# plt.figure(figsize = (14,10))
# sns.heatmap(corr_matrix, annot = True, cmap = 'BuGn')
# plt.show()

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x='oldpeak',y='ST segment',data=df,hue='heart disease',s=200,alpha=0.9,palette='Set2')
plt.legend(bbox_to_anchor=(1.2,0.5),title="heart disease")

# %%
feature = ['chest pain type', 'resting electrocardiographic results', 'ST segment', 'major vessels', 'thal']

for col in feature:
    print (f'{col} has {df[col].unique()} values\n')
    df[col] = df[col].astype(str)
# Out:
# chest pain type has ['4' '3' '2' '1'] values
#
# resting electrocardiographic results has ['2' '0' '1'] values
#
# ST segment has ['2' '1' '3'] values
#
# major vessels has ['3' '0' '1' '2'] values
#
# thal has ['3' '7' '6'] values

# %%
# need_bin = ['resting electrocardiographic results', 'ST segment', 'thal']

import category_encoders as ce

ce_be = ce.BinaryEncoder(cols = feature)

df_encoded = ce_be.fit_transform(df)

df = df_encoded

# %%
df.columns
# Out:
# Index(['age', 'sex ', 'chest pain type_0', 'chest pain type_1',
#        'chest pain type_2', 'resting blood pressure', 'serum cholestoral',
#        'fasting blood sugar', 'resting electrocardiographic results_0',
#        'resting electrocardiographic results_1', 'max heart rate',
#        'exercise induced angina', 'oldpeak', 'ST segment_0', 'ST segment_1',
#        'major vessels_0', 'major vessels_1', 'major vessels_2', 'thal_0',
#        'thal_1', 'heart disease'],
#       dtype='object')

# %%
print (cat_cols)
# Out:
# ['sex ', 'chest pain type', 'fasting blood sugar', 'resting electrocardiographic results', 'exercise induced angina', 'ST segment', 'major vessels', 'thal', 'heart disease']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   age                                     270 non-null    int64
#  1   sex                                     270 non-null    object
#  2   chest pain type_0                       270 non-null    int64
#  3   chest pain type_1                       270 non-null    int64
#  4   chest pain type_2                       270 non-null    int64
#  5   resting blood pressure                  270 non-null    int64
#  6   serum cholestoral                       270 non-null    int64
#  7   fasting blood sugar                     270 non-null    object
#  8   resting electrocardiographic results_0  270 non-null    int64
#  9   resting electrocardiographic results_1  270 non-null    int64
# ...

# %%
cat_news = ['sex ', 'fasting blood sugar', 'exercise induced angina', 'heart disease']
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in cat_news:
    df[col] = le.fit_transform(df[col])

# %%
df.describe()
# Out:
#               age        sex   chest pain type_0  chest pain type_1  \
# count  270.000000  270.000000         270.000000         270.000000
# mean    54.433333    0.677778           0.074074           0.448148
# std      9.109067    0.468195           0.262378           0.498228
# min     29.000000    0.000000           0.000000           0.000000
# 25%     48.000000    0.000000           0.000000           0.000000
# 50%     55.000000    1.000000           0.000000           0.000000
# 75%     61.000000    1.000000           0.000000           1.000000
# max     77.000000    1.000000           1.000000           1.000000
#
#        chest pain type_2  resting blood pressure  serum cholestoral  \
# count         270.000000              270.000000         270.000000
# mean            0.633333              131.344444         249.659259
# std             0.482789               17.861608          51.686237
# min             0.000000               94.000000         126.000000
# ...

# %%
df.head()
# Out:
#    age  sex   chest pain type_0  chest pain type_1  chest pain type_2  \
# 0   70     1                  0                  0                  1
# 1   67     0                  0                  1                  0
# 2   57     1                  0                  1                  1
# 3   64     1                  0                  0                  1
# 4   74     0                  0                  1                  1
#
#    resting blood pressure  serum cholestoral  fasting blood sugar  \
# 0                     130                322                    0
# 1                     115                564                    0
# 2                     124                261                    0
# 3                     128                263                    0
# 4                     120                269                    0
#
#    resting electrocardiographic results_0  \
# 0                                       0
# 1                                       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   age                                     270 non-null    int64
#  1   sex                                     270 non-null    int64
#  2   chest pain type_0                       270 non-null    int64
#  3   chest pain type_1                       270 non-null    int64
#  4   chest pain type_2                       270 non-null    int64
#  5   resting blood pressure                  270 non-null    int64
#  6   serum cholestoral                       270 non-null    int64
#  7   fasting blood sugar                     270 non-null    int64
#  8   resting electrocardiographic results_0  270 non-null    int64
#  9   resting electrocardiographic results_1  270 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex ', 'chest pain type_0', 'chest pain type_1',
#        'chest pain type_2', 'resting blood pressure', 'serum cholestoral',
#        'fasting blood sugar', 'resting electrocardiographic results_0',
#        'resting electrocardiographic results_1', 'max heart rate',
#        'exercise induced angina', 'oldpeak', 'ST segment_0', 'ST segment_1',
#        'major vessels_0', 'major vessels_1', 'major vessels_2', 'thal_0',
#        'thal_1', 'heart disease'],
#       dtype='object')

# %%
ind_col = [col for col in df.columns if col != 'heart disease']
dep_col = 'heart disease'

x = df[ind_col]
y = df[dep_col]
corr_matrix = x.corr()
# print (y)

# %%
import seaborn as sns
plt.figure(figsize = (14,10))
sns.heatmap(corr_matrix, annot = True, cmap = 'BuGn')
plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42, stratify=y)
# y_train = le.fit_transform(y_train)

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import svm

from sklearn.model_selection import cross_val_score

from sklearn.metrics import roc_curve, roc_auc_score
import scikitplot as skplt

# %%
# objective = 'binary:logistic', learning_rate = 0.5, max_depth =5, n_estimators = 170

# Define the parameter grid for grid search
param_grid = {
    'learning_rate': [0.1, 0.3, 0.5],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300]
}

# Initialize the XGBoost classifier
xgb = XGBClassifier()

# Perform Grid Search Cross Validation
grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=3, scoring='accuracy')
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Train XGBoost with best parameters
best_xgb = XGBClassifier(objective = 'binary:logistic', learning_rate = 0.1, max_depth =5, n_estimators = 100, reg_lambda = 0, reg_alpha = 0, colsample_bytree= 0.54)  # Use your best hyperparameters, min_child_weight = 3
best_xgb.fit(x_train, y_train)

# Evaluate the model on test data
xgb_acc = best_xgb.score(x_test, y_test)

print(f"Training Accuracy of XgBoost is {accuracy_score(y_train, best_xgb.predict(x_train))}")
print(f"Test Accuracy of XgBoost is {xgb_acc}")
# print(f"5 K-Fold accuracy of XgBoost is {xgb_cv} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, best_xgb.predict(x_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, best_xgb.predict(x_test))}")
# Out:
# Training Accuracy of XgBoost is 1.0
# Test Accuracy of XgBoost is 0.8765432098765432
# Confusion Matrix :-
# [[38  7]
#  [ 3 33]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88        45
#            1       0.82      0.92      0.87        36
#
#     accuracy                           0.88        81
#    macro avg       0.88      0.88      0.88        81
# weighted avg       0.88      0.88      0.88        81

# %%
rd_clf = RandomForestClassifier()
# criterion = 'entropy', max_depth = 11, max_features = 'auto', min_samples_leaf = 2, min_samples_split = 3, n_estimators = 130
rd_clf.fit(x_train, y_train)

# accuracy score, confusion matrix and classification report of random forest

rd_clf_acc = accuracy_score(y_test, rd_clf.predict(x_test))

print(f"Training Accuracy of Random Forest Classifier is {accuracy_score(y_train, rd_clf.predict(x_train))}")
print(f"Test Accuracy of Random Forest Classifier is {rd_clf_acc} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, rd_clf.predict(x_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, rd_clf.predict(x_test))}")
# Out:
# Training Accuracy of Random Forest Classifier is 1.0
# Test Accuracy of Random Forest Classifier is 0.8395061728395061
#
# Confusion Matrix :-
# [[38  7]
#  [ 6 30]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85        45
#            1       0.81      0.83      0.82        36
#
#     accuracy                           0.84        81
#    macro avg       0.84      0.84      0.84        81
# weighted avg       0.84      0.84      0.84        81

# %%
rd_clf_1 = RandomForestClassifier(max_depth =10, n_estimators = 180, criterion = 'entropy')
# criterion = 'entropy', max_depth = 11, max_features = 'auto', min_samples_leaf = 2, min_samples_split = 3, n_estimators = 130
rd_clf_1.fit(x_train, y_train)

# accuracy score, confusion matrix and classification report of random forest

rd_clf_1_acc = accuracy_score(y_test, rd_clf_1.predict(x_test))

print(f"Training Accuracy of Random Forest Classifier is {accuracy_score(y_train, rd_clf_1.predict(x_train))}")
print(f"Test Accuracy of Random Forest Classifier is {rd_clf_1_acc} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, rd_clf.predict(x_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, rd_clf_1.predict(x_test))}")
# Out:
# Training Accuracy of Random Forest Classifier is 1.0
# Test Accuracy of Random Forest Classifier is 0.8518518518518519
#
# Confusion Matrix :-
# [[38  7]
#  [ 6 30]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86        45
#            1       0.82      0.86      0.84        36
#
#     accuracy                           0.85        81
#    macro avg       0.85      0.85      0.85        81
# weighted avg       0.85      0.85      0.85        81

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

gnb = GaussianNB(var_smoothing=1e-9)
gnb.fit(x_train, y_train)
gnb_acc = accuracy_score(y_test, gnb.predict(x_test))

gnb_cv = cross_val_score(gnb, x, y, scoring = 'accuracy', cv = 10)

y_scores = gnb.predict_proba(x_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_scores)
auc = roc_auc_score(y_test, y_scores)

print(f"Training Accuracy of Naive Bayes Classifier is {accuracy_score(y_train, gnb.predict(x_train))}")
print(f"Test Accuracy of Naive Bayes Classifier is {gnb_acc}")
print(f"10 K-Fold accuracy of Naive Bayes Classifier is {gnb_cv}")
print(f"Means Accuracy = {gnb_cv.mean()}, Standard deviation = {gnb_cv.std()}\n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, gnb.predict(x_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, gnb.predict(x_test))}")

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line for random classifier
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Naive Bayes Classifier')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# Training Accuracy of Naive Bayes Classifier is 0.8359788359788359
# Test Accuracy of Naive Bayes Classifier is 0.9012345679012346
# 10 K-Fold accuracy of Naive Bayes Classifier is [0.81481481 0.77777778 0.85185185 0.85185185 0.96296296 0.85185185
#  0.77777778 0.85185185 0.92592593 0.77777778]
# Means Accuracy = 0.8444444444444444, Standard deviation = 0.05925925925925925
#
# Confusion Matrix :-
# [[38  7]
#  [ 1 35]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90        45
#            1       0.83      0.97      0.90        36
#
#     accuracy                           0.90        81
#    macro avg       0.90      0.91      0.90        81
# weighted avg       0.91      0.90      0.90        81

# %%
k = range(10,30)
train_acc = []
test_acc = []
neighbors = []

for i in k:
    neighbors.append(i)
    gnb = GaussianNB(var_smoothing=1e-9)
    gnb.fit(x_train, y_train)
    train_acc.append(accuracy_score(y_train, gnb.predict(x_train)))
    test_acc.append(accuracy_score(y_test, gnb.predict(x_test)))

plt.figure(figsize = (8,6))
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.title('Variation of Accuracy with k')
plt.plot(neighbors, train_acc, color = 'blue', linewidth = 1,
         label = 'train accuracy');

plt.plot(neighbors, test_acc, color = 'red', linewidth = 2,
         label = 'test accuracy')
plt.legend()
plt.show();

# %%
# svm_model = svm.SVC(kernel='rbf', C=12, gamma='auto')  # RBF kernel is common, adjust C and gamma as needed

# svm_model.fit(x_train, y_train)

param_grid = {
    'C': [0.1, 1, 10],  # Regularization parameter
    'gamma': ['scale', 'auto'],  # Kernel coefficient
    'kernel': ['rbf', 'linear', 'poly']  # Kernel type
}

# Initialize SVM classifier
svm_model = svm.SVC()

# Perform Grid Search Cross Validation
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=3, scoring='accuracy')
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Train SVM with best parameters
best_svm = svm.SVC(kernel='rbf', C=12, gamma='auto')

best_svm.fit(x_train, y_train)

svm_model_acc = accuracy_score(y_test, best_svm.predict(x_test))

print(f"Training Accuracy of Support Vector Machines is {accuracy_score(y_train, best_svm.predict(x_train))}")
print(f"Test Accuracy of Support Vector Machines is {svm_model_acc}\n")
# print(f"5 K-Fold accuracy of Support Vector Machines is {best_svm_cv} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, best_svm.predict(x_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, best_svm.predict(x_test))}")
# Out:
# Training Accuracy of Support Vector Machines is 1.0
# Test Accuracy of Support Vector Machines is 0.8395061728395061
#
# Confusion Matrix :-
# [[34 11]
#  [ 2 34]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84        45
#            1       0.76      0.94      0.84        36
#
#     accuracy                           0.84        81
#    macro avg       0.85      0.85      0.84        81
# weighted avg       0.86      0.84      0.84        81

# %%
# Model Comparision

# %%
models = pd.DataFrame({
    'Model' : ['XgBoost', 'Random Forest Classifier', 'Naive Bayes Classifier', 'Support Vector Machines' ],
    'Score' : [xgb_acc, rd_clf_1_acc, gnb_acc, svm_model_acc]
})


models.sort_values(by = 'Score', ascending = False)
# Out:
#                       Model     Score
# 2    Naive Bayes Classifier  0.901235
# 0                   XgBoost  0.876543
# 1  Random Forest Classifier  0.851852
# 3   Support Vector Machines  0.839506

# %%
import plotly.express as px
px.bar(data_frame = models, x = 'Score', y = 'Model', color = 'Score', 
       title = 'Models Comparison', )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/quan/lib/python3.8/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/miniconda3/envs/quan/lib/python3.8/site-packages/plotly/basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~/miniconda3/envs/quan/lib/python3.8/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
# ...
